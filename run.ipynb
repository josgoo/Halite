# %%
from kaggle_environments import make
env = make("halite", debug=True)
env.run(["submission.py", 'random', 'random', 'random'])
#env.render(mode="ipython", width=800, height=600)
# Out:
# [{'ship_positions': [(5, 15)], 'enemy_vectors': {'0-2': (0, 0), '0-3': (0, 0), '0-4': (0, 0)}, 'dropoff': {'point': (5, 15), 'value': inf}, 'spawn': [], 'dominance': {'0-1': [{'point': (17, 15), 'value': 0.976}, {'point': (16, 16), 'value': 0.9520000000000001}, {'point': (15, 17), 'value': 0.976}, {'point': (16, 14), 'value': 0.9520000000000001}, {'point': (15, 13), 'value': 0.976}, {'point': (14, 14), 'value': 0.9520000000000001}, {'point': (13, 15), 'value': 0.976}, {'point': (14, 16), 'value': 0.9520000000000001}, {'point': (16, 15), 'value': 0.856}, {'point': (15, 16), 'value': 0.856}, {'point': (14, 15), 'value': 0.856}, {'point': (15, 14), 'value': 0.856}, {'point': (15, 15), 'value': 0.4}, {'point': (7, 5), 'value': 0.976}, {'point': (6, 6), 'value': 0.9520000000000001}, {'point': (5, 7), 'value': 0.976}, {'point': (6, 4), 'value': 0.9520000000000001}, {'point': (5, 3), 'value': 0.976}, {'point': (4, 4), 'value': 0.9520000000000001}, {'point': (3, 5), 'value': 0.976}, {'point': (4, 6), 'value': 0.95200[{'ship_positions': [(5, 15)], 'enemy_vectors': {'0-2': (0, 0), '0-3': (-1, 0), '0-4': (1, 0)}, 'dropoff': {'point': (5, 15), 'value': inf}, 'spawn': [], 'dominance': {'0-1': [{'point': (17, 15), 'value': 0.976}, {'point': (16, 16), 'value': 0.9520000000000001}, {'point': (15, 17), 'value': 0.976}, {'point': (16, 14), 'value': 0.9520000000000001}, {'point': (15, 13), 'value': 0.976}, {'point': (14, 14), 'value': 0.9520000000000001}, {'point': (13, 15), 'value': 0.976}, {'point': (14, 16), 'value': 0.9520000000000001}, {'point': (16, 15), 'value': 0.856}, {'point': (15, 16), 'value': 0.856}, {'point': (14, 15), 'value': 0.856}, {'point': (15, 14), 'value': 0.856}, {'point': (15, 15), 'value': 0.4}, {'point': (7, 5), 'value': 0.976}, {'point': (6, 6), 'value': 0.9520000000000001}, {'point': (5, 7), 'value': 0.976}, {'point': (6, 4), 'value': 0.9520000000000001}, {'point': (5, 3), 'value': 0.976}, {'point': (4, 4), 'value': 0.9520000000000001}, {'point': (3, 5), 'value': 0.976}, {'point': (4, 6), 'value': 0.9520[{'ship_positions': [(5, 15)], 'enemy_vectors': {'0-2': (0, 0), '0-3': (-1, 0), '0-4': (0, 0), '2-2': (0, 0)}, 'dropoff': {'point': (5, 15), 'value': inf}, 'spawn': [], 'dominance': {'0-1': [{'point': (17, 15), 'value': 0.976}, {'point': (16,
0), '0-3': (-1, 0), '0-4': (0, 0), '2-2': (0, 0), '3-2': (-1, 0), '4-2': (1, 1), '8-2': (-2, 1), '9-2': (0, -1), '11-1': (0, 1)}, 'dropoff': {'point': (5, 15), 'value': inf}, 'spawn': [], 'dominance': {'0-1': [{'point': (17, 15), 'value': 0.976}, {'point': (16, 16), 'value': 0.9520000000000001}, {'point': (15, 17), 'value': 0.976}, {'point': (16, 14), 'value': 0.9520000000000001}, {'point': (15, 13), 'value': 0.976}, {'point': (14, 14), 'value': 0.9520000000000001}, {'point': (13, 15), 'value': 0.976}, {'point': (14, 16), 'value': 0.9520000000000001}, {'point': (16, 15), 'value': 0.856}, {'point': (15, 16), 'value': 0.856}, {'point': (14, 15), 'value': 0.856}, {'point': (15, 14), 'value': 0.856}, {'point': (15, 15), 'value': 0.4}, {'point': (7, 5), 'value': 0.976}, {'point': (6, 6), 'value': 0.9520000000000001}, {'point': (5, 7), 'value': 0.976}, {'point': ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-12bbf251c882> in <module>
#       1 from kaggle_environments import make
#       2 env = make("halite", debug=True)
# ----> 3 env.run(["submission.py", 'random', 'random', 'random'])
#       4 #env.render(mode="ipython", width=800, height=600)
#
# c:\python38\lib\site-packages\kaggle_environments\core.py in run(self, agents)
#     225         start = perf_counter()
#     226         while not self.done and perf_counter() - start < self.configuration.runTimeout:
# --> 227             actions, logs = runner.act()
#     228             self.step(actions, logs)
#     229         return self.steps
#
# c:\python38\lib\site-packages\kaggle_environments\core.py in act(none_action)
#     593                 results = self.pool.map(act_agent, act_args)
#     594             else:
# --> 595                 results = list(map(act_agent, act_args))
#     596
#     597             actions, logs = zip(*results)
#
# c:\python38\lib\site-packages\kaggle_environments\core.py in act_agent(args)
#      93         return none_action, {}
#      94     else:
# ---> 95         return agent.act(state["observation"])
#      96
#      97
#
# c:\python38\lib\site-packages\kaggle_environments\agent.py in act(self, observation)
#     157             try:
#     158                 start = perf_counter()
# --> 159                 action = self.agent(*args)
#     160             except Exception as e:
#     161                 traceback.print_exc(file=err_buffer)
#
# c:\python38\lib\site-packages\kaggle_environments\agent.py in callable_agent(observation, configuration)
#     120
#     121         return \
# --> 122             agent(*args) \
#     123             if callable(agent) \
#     124             else agent
#
# <string> in agent(obs, config)
#
# c:\python38\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     178     # a debuggability cost
#     179     for chunk in iterable:
# --> 180         fp.write(chunk)
#     181
#     182
#
# KeyboardInterrupt:

# %%
j = env.toJSON()

# %%
import json
with open('log.txt') as json_file:
    data = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-41-806d9bab41fc> in <module>
#       1 import json
#       2 with open('log.txt') as json_file:
# ----> 3     data = json.load(json_file)
#
# c:\python38\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# c:\python38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# c:\python38\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\python38\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 417966 (char 417965)
